# %%
for i in [1,2,3,4]:
    sq = i**3
    print(sq)
    print(i**3)
# Out:
# 1
# 1
# 8
# 8
# 27
# 27
# 64
# 64

# %%
def product (x,y):
    return x*y

product(2,5)
# Out:
# 10

# %%
def areacircle (r):
    r2 = product (r,r)
    area = product (r2, 3.14159)
    return area
areacircle(2)

# %%
for i in range(1,11):
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
mymatrix=[[1,2,3],[4,5,6]]
print(mymatrix)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
for i in mymatrix:
    for j in i:
        print(j**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36

# %%
mymatrix=[[1,2,3],[4,5,6],[7,8,9]]
print(mymatrix)

for i in range(3):
    for j in range(3):
        mymatrix [i][j] **= 2
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
x = 432
while x > 100:
    x -= 10
print(x)

# %%
mylist = [x**2 for x in range (1,11)]
print(mylist)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
